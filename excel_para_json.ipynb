# %%
import pandas as pd

# %%
df = pd.read_excel('agendamento_202606121322_formatado.xlsx')
display(df.head())
# Out:
#    Código do agendamento Data do agendamento Hora início Hora fim  \
# 0                  46619          2021-04-09       09:00    09:40
# 1                  46620          2021-04-09       09:40    10:00
# 2                  46621          2021-04-09       11:20    11:40
# 3                  46622          2021-04-09       16:00    16:20
# 4                  46623          2021-04-09       16:20    16:40
#
#   CPF do assistido                  Nome do assistido Organização  Serviço  \
# 0   301.568.311-04   SUYAN SANTANNA BATISTA DE MATTOS   SINPRO/DF      NaN
# 1   143.492.051-87   RAIMUNDO NONATO NEVES DE MENEZES   SINPRO/DF      NaN
# 2   428.329.773-91  LEILA LOPES DA SILVA MOTA CAMPELO   SINPRO/DF      NaN
# 3   555.355.006-82   RITA DE CASSIA DE OLIVEIRA SILVA   SINPRO/DF      NaN
# 4   390.680.219-15                     DAVID LANGRAFE   SINPRO/DF      NaN
#
#    Local         Responsável pelo agendamento  Criado por     Data de criação  \
# ...

# %%
df.to_json('atendimentos.json', orient='records', indent=4)
# Out:
# C:\Users\guilh\AppData\Local\Temp\ipykernel_8988\384697645.py:1: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   df.to_json('atendimentos.json', orient='records', indent=4)

# %%
json_file = pd.read_json('atendimentos.json')
display(json_file.head())
# Out:
#    Código do agendamento  Data do agendamento Hora início Hora fim  \
# 0                  46619        1617926400000       09:00    09:40
# 1                  46620        1617926400000       09:40    10:00
# 2                  46621        1617926400000       11:20    11:40
# 3                  46622        1617926400000       16:00    16:20
# 4                  46623        1617926400000       16:20    16:40
#
#   CPF do assistido                  Nome do assistido Organização  Serviço  \
# 0   301.568.311-04   SUYAN SANTANNA BATISTA DE MATTOS   SINPRO/DF      NaN
# 1   143.492.051-87   RAIMUNDO NONATO NEVES DE MENEZES   SINPRO/DF      NaN
# 2   428.329.773-91  LEILA LOPES DA SILVA MOTA CAMPELO   SINPRO/DF      NaN
# 3   555.355.006-82   RITA DE CASSIA DE OLIVEIRA SILVA   SINPRO/DF      NaN
# 4   390.680.219-15                     DAVID LANGRAFE   SINPRO/DF      NaN
#
#    Local         Responsável pelo agendamento  Criado por  Data de criação  \
# ...
